# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
income_filepath = 'C:/Users/Marta/Downloads/Coinbase-600466a0d5473e099dcdfcbf-TransactionsHistoryReport-2023-08-31-10-50-37.csv'

income_df = pd.read_csv(income_filepath, delimiter=',', skiprows=7)
income_df
# Out:
#                 Timestamp    Transaction Type Asset  Quantity Transacted  \
# 0    2021-03-14T11:55:09Z                 Buy   BTC         9.581100e-04
# 1    2021-03-14T12:00:26Z             Receive   BTC         1.670000e-04
# 2    2022-11-12T06:35:50Z  Advanced Trade Buy   BTC         6.146900e-03
# 3    2022-11-12T06:35:50Z  Advanced Trade Buy   BTC         2.470000e-06
# 4    2022-11-12T06:35:51Z  Advanced Trade Buy   BTC         2.100000e-07
# ..                    ...                 ...   ...                  ...
# 391  2022-10-20T19:04:30Z     Learning Reward   XCN         1.501163e+01
# 392  2022-10-20T19:04:52Z     Learning Reward   XCN         1.501163e+01
# 393  2022-10-20T19:02:36Z     Learning Reward    00         1.800018e+00
# 394  2022-10-20T19:02:57Z     Learning Reward    00         1.797591e+00
# 395  2022-10-20T19:03:20Z     Learning Reward    00         1.797107e+00
#
#     Spot Price Currency  Spot Price at Transaction   Subtotal  \
# ...
